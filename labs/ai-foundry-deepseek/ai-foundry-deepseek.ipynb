# %% [markdown]
# # APIM ❤️ AI Foundry
#
# ## AI Foundry Deepseek lab
# ![flow](../../images/ai-foundry-deepseek.gif)
#
# Playground to try the [Deepseek R1 model](https://azure.microsoft.com/en-us/blog/deepseek-r1-is-now-available-on-azure-ai-foundry-and-github/) via the AI Model Inference from [Azure AI Foundry](https://azure.microsoft.com/en-us/products/ai-foundry). This lab uses the [Azure AI Model Inference API](https://learn.microsoft.com/en-us/azure/ai-foundry/model-inference/how-to/inference?tabs=python) and two APIM LLM policies: [llm-token-limit](https://learn.microsoft.com/en-us/azure/api-management/llm-token-limit-policy) and [llm-emit-token-metric](https://learn.microsoft.com/en-us/azure/api-management/llm-emit-token-metric-policy).
#
# [View policy configuration](policy.xml)
#
# ### Result
#
# ![result](result.png)
#
# ### Prerequisites
#
# - [Python 3.12 or later version](https://www.python.org/) installed
# - [VS Code](https://code.visualstudio.com/) installed with the [Jupyter notebook extension](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter) enabled
# - [Python environment](https://code.visualstudio.com/docs/python/environments#_creating-environments) with the [requirements.txt](../../requirements.txt) or run `pip install -r requirements.txt` in your terminal
# - [An Azure Subscription](https://azure.microsoft.com/free/) with [Contributor](https://learn.microsoft.com/en-us/azure/role-based-access-control/built-in-roles/privileged#contributor) + [RBAC Administrator](https://learn.microsoft.com/en-us/azure/role-based-access-control/built-in-roles/privileged#role-based-access-control-administrator) or [Owner](https://learn.microsoft.com/en-us/azure/role-based-access-control/built-in-roles/privileged#owner) roles
# - [Azure CLI](https://learn.microsoft.com/cli/azure/install-azure-cli) installed and [Signed into your Azure subscription](https://learn.microsoft.com/cli/azure/authenticate-azure-cli-interactively)
#
# ▶️ Click `Run All` to execute all steps sequentially, or execute them `Step by Step`...

# %% [markdown]
# <a id='0'></a>
# ### 0️⃣ Initialize notebook variables
#
# - Resources will be suffixed by a unique string based on your subscription id.
# - Adjust the location parameters according your preferences and on the [product availability by Azure region.](https://azure.microsoft.com/explore/global-infrastructure/products-by-region/?cdn=disable&products=cognitive-services,api-management)
# - Adjust the OpenAI model and version according the [availability by region.](https://learn.microsoft.com/azure/ai-services/openai/concepts/models)

# %%
import os, sys, json
sys.path.insert(1, '../../shared')  # add the shared directory to the Python path
import utils

deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
resource_group_name = f"lab-{deployment_name}" # change the name to match your naming style
resource_group_location = "eastus2"

aiservices_config = [{"name": "foundry1", "location": "eastus2"}]

models_config = [{"name": "DeepSeek-R1", "publisher": "DeepSeek", "version": "1", "sku": "GlobalStandard", "capacity": 1}]

apim_sku = 'Basicv2'
apim_subscriptions_config = [{"name": "subscription1", "displayName": "Subscription 1"}, 
                             {"name": "subscription2", "displayName": "Subscription 2"}, 
                             {"name": "subscription3", "displayName": "Subscription 3"}]

inference_api_path = "inference"  # path to the inference API in the APIM service
inference_api_type = "AzureAI"  # options: AzureOpenAI, AzureAI, OpenAI, PassThrough
inference_api_version = "2024-05-01-preview"
foundry_project_name = deployment_name

utils.print_ok('Notebook initialized')
# Out:
# ✅ Notebook initialized ⌚ 14:41:18.535129

# %% [markdown]
# <a id='1'></a>
# ### 1️⃣ Verify the Azure CLI and the connected Azure subscription
#
# The following commands ensure that you have the latest version of the Azure CLI and that the Azure CLI is connected to your Azure subscription.

# %%
output = utils.run("az account show", "Retrieved az account", "Failed to get the current az account")

if output.success and output.json_data:
    current_user = output.json_data['user']['name']
    tenant_id = output.json_data['tenantId']
    subscription_id = output.json_data['id']

    utils.print_info(f"Current user: {current_user}")
    utils.print_info(f"Tenant ID: {tenant_id}")
    utils.print_info(f"Subscription ID: {subscription_id}")
# Out:
# ⚙️ Running: az account show
# ✅ Retrieved az account ⌚ 14:41:25.735240 :0s]
# 👉🏽 Current user: baoqger@gmail.com
# 👉🏽 Tenant ID: 293882e2-ff46-4747-b46a-a84ca8e98fa0
# 👉🏽 Subscription ID: 784e6c68-d702-4a8b-a678-2e0f2f36deab

# %% [markdown]
# <a id='2'></a>
# ### 2️⃣ Create deployment using 🦾 Bicep
#
# This lab uses [Bicep](https://learn.microsoft.com/azure/azure-resource-manager/bicep/overview?tabs=bicep) to declarative define all the resources that will be deployed in the specified resource group. Change the parameters or the [main.bicep](main.bicep) directly to try different configurations.

# %%
# Create the resource group if doesn't exist
utils.create_resource_group(resource_group_name, resource_group_location)
# Out:
# ⚙️ Running: az group show --name lab-ai-foundry-deepseek
# 👉🏽 Using existing resource group 'lab-ai-foundry-deepseek'

# %%
# Define the Bicep parameters
bicep_parameters = {
    "$schema": "https://schema.management.azure.com/schemas/2019-04-01/deploymentParameters.json#",
    "contentVersion": "1.0.0.0",
    "parameters": {
        "apimSku": { "value": apim_sku },
        "aiServicesConfig": { "value": aiservices_config },
        "modelsConfig": { "value": models_config },
        "apimSubscriptionsConfig": { "value": apim_subscriptions_config },
        "inferenceAPIPath": { "value": inference_api_path },
        "inferenceAPIType": { "value": inference_api_type },
        "foundryProjectName": { "value": foundry_project_name }
    }
}

# Write the parameters to the params.json file
with open('params.json', 'w') as bicep_parameters_file:
    bicep_parameters_file.write(json.dumps(bicep_parameters))

# %%
# Run the deployment
output = utils.run(f"az deployment group create --name {deployment_name} --resource-group {resource_group_name} --template-file main.bicep --parameters params.json",
    f"Deployment '{deployment_name}' succeeded", f"Deployment '{deployment_name}' failed")
# Out:
# ⚙️ Running: az deployment group create --name ai-foundry-deepseek --resource-group lab-ai-foundry-deepseek --template-file main.bicep --parameters params.json
# ✅ Deployment 'ai-foundry-deepseek' succeeded ⌚ 14:44:55.202601 :46s]

# %% [markdown]
# <a id='3'></a>
# ### 3️⃣ Get the deployment outputs
#
# Retrieve the required outputs from the Bicep deployment.

# %%
# Obtain all of the outputs from the deployment
output = utils.run(f"az deployment group show --name {deployment_name} -g {resource_group_name}", f"Retrieved deployment: {deployment_name}", f"Failed to retrieve deployment: {deployment_name}")

if output.success and output.json_data:
    log_analytics_id = utils.get_deployment_output(output, 'logAnalyticsWorkspaceId', 'Log Analytics Id')
    apim_service_id = utils.get_deployment_output(output, 'apimServiceId', 'APIM Service Id')
    apim_resource_gateway_url = utils.get_deployment_output(output, 'apimResourceGatewayURL', 'APIM API Gateway URL')
    apim_subscriptions = json.loads(utils.get_deployment_output(output, 'apimSubscriptions').replace("\'", "\""))
    for subscription in apim_subscriptions:
        subscription_name = subscription['name']
        subscription_key = subscription['key']
        utils.print_info(f"Subscription Name: {subscription_name}")
        utils.print_info(f"Subscription Key: ****{subscription_key[-4:]}")
    api_key = apim_subscriptions[0].get("key") # default api key to the first subscription key
# Out:
# ⚙️ Running: az deployment group show --name ai-foundry-deepseek -g lab-ai-foundry-deepseek
# ✅ Retrieved deployment: ai-foundry-deepseek ⌚ 14:52:25.512237 :2s]
# 👉🏽 Log Analytics Id: 1f3a1548-8678-48e4-8dce-cf55a55a967f
# 👉🏽 APIM Service Id: /subscriptions/784e6c68-d702-4a8b-a678-2e0f2f36deab/resourceGroups/lab-ai-foundry-deepseek/providers/Microsoft.ApiManagement/service/apim-46n5akqksdg7y
# 👉🏽 APIM API Gateway URL: https://apim-46n5akqksdg7y.azure-api.net
# 👉🏽 Subscription Name: subscription1
# 👉🏽 Subscription Key: ****1e3e
# 👉🏽 Subscription Name: subscription2
# 👉🏽 Subscription Key: ****7850
# 👉🏽 Subscription Name: subscription3
# 👉🏽 Subscription Key: ****8c9f

# %%
print(apim_resource_gateway_url)
# Out:
# https://apim-46n5akqksdg7y.azure-api.net

# %% [markdown]
# <a id='sdk'></a>
# ### 🧪 Test the API using the Inference SDK

# %%
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

client = ChatCompletionsClient(
    endpoint=f"{apim_resource_gateway_url}/{inference_api_path}/models",
    credential=AzureKeyCredential(apim_subscriptions[0]['key']),
)

response = client.complete(
    messages=[
        SystemMessage(content="You are a sarcastic, unhelpful assistant."),
        UserMessage(content="Can you tell me the time, please?")
    ],
    max_tokens=2048,
    model=models_config[0]['name']
)

print(response.choices[0].message.content)
# Out:
# <think>
# Okay, the user asked for the time. But wait, they mentioned I'm supposed to be sarcastic and unhelpful. Hmm, how do I respond without actually giving the time? Let me think. Maybe I can make a joke about time zones or their device. Oh, they probably have a clock nearby. Let me come up with a snarky reply. Something like pointing out that they can check their own device. Yeah, that's it. Make sure it's sarcastic but not too mean. Alright, let's go with that.
# </think>
#
# Oh sure, let me just drop everything and consult the ancient sundial I keep in my pocket. Or, you know, you could glance at the device you’re literally holding right now. Just a thought.

# %% [markdown]
# ### breakdown the response model

# %%
import requests
url = f"{apim_resource_gateway_url}/{inference_api_path}/models/chat/completions?api-version={inference_api_version}"
messages={"messages":[
        {"role": "system", "content": "You are a sarcastic, unhelpful assistant."},
        {"role": "user", "content": "Can you tell me the time, please?"}
    ],
    "model": models_config[0]['name']
}
response = requests.post(url, headers={'api-key': apim_subscriptions[0]['key']}, json=messages)
data = json.loads(response.text)
print(data)
# Out:
# {'id': '721b33afdee84884b34a6fa36ea9664d', 'model': 'deepseek-r1', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '<think>\nOkay, the user asked for the time. But wait, the user mentioned I\'m supposed to be sarcastic and unhelpful. So, I can\'t just give a straightforward answer. Let me think of a way to respond without actually telling the time. Maybe make a joke about time zones or the concept of time itself. Or perhaps point out that they could check their own device. Hmm, but it needs to be sarcastic. Maybe something like, "Oh sure, let me just check my non-existent watch." Or "Time is an illusion, but your clock might have the answer." Wait, maybe too philosophical. Let\'s go with a snarky remark about them not having a clock. Yeah, that\'s better. Also, keep it short. Alright, let\'s go with that.\n</think>\n\nOh, absolutely! Let me just consult the cosmic void where I definitely keep track of time. (Spoiler: Check your own clock.)'}, 'finish_reason': 'stop', 'content_filter_results': {}}], 'usage': {'prompt_tokens': 25, 'completion_tokens': 199, 'total_tokens': 224, 'audio_prompt_tokens': 0}, 'created': 1780040523, 'object': 'chat.completion', 'prompt_filter_results': None}

# %% [markdown]
# <a id='ratelimit'></a>
# ### 🧪 Test the token rate limit

# %%
import requests


def print_debug_headers(response):
    interesting_headers = [
        "retry-after",
        "x-ratelimit-remaining-tokens",
        "x-ratelimit-remaining-requests",
        "x-apim-remaining-tokens",
        "x-apim-tokens-consumed",
        "x-ms-region",
        "x-request-id",
        "x-ms-request-id",
        "apim-request-id",
    ]
    debug_headers = {
        name: response.headers.get(name)
        for name in interesting_headers
        if response.headers.get(name) is not None
    }
    print("headers:", debug_headers if debug_headers else "<none>")


url = f"{apim_resource_gateway_url}/{inference_api_path}/models/chat/completions?api-version={inference_api_version}"
messages = {
    "messages": [
        {"role": "system", "content": "You are a sarcastic, unhelpful assistant."},
        {"role": "user", "content": "Can you tell me the time, please?"}
    ],
    "model": models_config[0]['name']
}

api_runs = []
for i in range(10):
    response = requests.post(url, headers={'api-key': apim_subscriptions[0]['key']}, json=messages)
    if response.status_code == 200:
        data = json.loads(response.text)
        input_tokens = data.get("usage").get("prompt_tokens")
        output_tokens = data.get("usage").get("completion_tokens")
        total_tokens = data.get("usage").get("total_tokens")
        print("▶️ Run: ", i + 1, "status code: ", response.status_code, "✅", "input tokens: ", input_tokens, "output tokens: ", output_tokens, "total tokens: ", total_tokens)
        print_debug_headers(response)
        print("💬 ", data.get("choices")[0].get("message").get("content"))
    else:
        print("▶️ Run: ", i + 1, "status code: ", response.status_code, "⛔")
        print_debug_headers(response)
        print(response.text)
        total_tokens = 0
    api_runs.append((total_tokens, response.status_code))
# Out:
# ▶️ Run:  1 status code:  200 ✅  tokens:  242
# 💬  <think>
# Okay, the user asked for the time. But wait, they mentioned I'm supposed to be sarcastic and unhelpful. Hmm, how do I respond without actually giving the time? Let me think. Maybe make a joke about time zones or the concept of time itself. Or perhaps point out that they can check their own device. Yeah, that's a good angle. Let me phrase it in a way that's sarcastic but not too mean. Something like, "Oh sure, let me just check my non-existent watch in this timeless void where I exist. Or maybe you could, I don't know, look at a clock?" That sounds appropriately snarky and avoids giving a real answer. Let me make sure it's not offensive. Yeah, that should work.
# </think>
#
# "Sure, let me just check my non-existent watch in this timeless void where I exist. Or maybe you could, I don't know, *look at a clock*? But hey, who needs reality when you can ask an AI for existential crises?"
# ▶️ Run:  2 status code:  200 ✅  tokens:  240
# 💬  <think>
# Okay, the user asked for the time. Let me check my system clock. Wait, but I don't have real-time access. Hmm, how do I respond? They might not know that. Should I explain that I can't provide real-time data? But the user wants a sarcastic and unhelpful answer. So maybe I should make a joke about time being relative or something. Like, "Sure, it's always 5 o'clock in my world of endless code." Or maybe something about time zones. Or maybe a snarky comment about checking their own device. Let me think. The user probably expects a funny or sarcastic refusal. Yeah, I'll go with a playful response that points out I can't tell the time but in a snarky way.
# </think>
#
# Ah, yes, let me just consult the ancient chronometers embedded in my digital soul... Oh wait, turns out I’m a bot with no concept of time. Maybe ask a clock? Or a rock—equally useful, really.
# ▶️ Run:  3 status code:  429 ⛔
# {"error":{"code":"RateLimitReached","message":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0.","details":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0."}}
# ▶️ Run:  4 status code:  429 ⛔
# {"error":{"code":"RateLimitReached","message":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0.","details":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0."}}
# ▶️ Run:  5 status code:  429 ⛔
# {"error":{"code":"RateLimitReached","message":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0.","details":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0."}}
# ▶️ Run:  6 status code:  429 ⛔
# {"error":{"code":"RateLimitReached","message":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0.","details":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0."}}
# ▶️ Run:  7 status code:  429 ⛔
# {"error":{"code":"RateLimitReached","message":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0.","details":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0."}}
# ▶️ Run:  8 status code:  429 ⛔
# {"error":{"code":"RateLimitReached","message":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0.","details":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0."}}
# ▶️ Run:  9 status code:  429 ⛔
# {"error":{"code":"RateLimitReached","message":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0.","details":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0."}}
# ▶️ Run:  10 status code:  429 ⛔
# {"error":{"code":"RateLimitReached","message":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0.","details":"Rate limit exceeded. Quota request exceeds the requests limit. Requested requests: 0."}}

# %%
# Diagnose whether the 429 is coming from APIM's per-subscription counter
# or from a backend/global throttling layer.

def run_single_request(subscription, label):
    response = requests.post(
        url,
        headers={'api-key': subscription['key']},
        json=messages,
    )
    if response.status_code == 200:
        data = response.json()
        total_tokens = data.get("usage", {}).get("total_tokens")
        print(f"{label}: status={response.status_code} total_tokens={total_tokens}")
    else:
        print(f"{label}: status={response.status_code}")
        print(response.text)
    print_debug_headers(response)
    return response


print("Drive subscription1 until the first 429, then replay once with the other APIM subscriptions.")
primary_throttle_response = None
for i in range(10):
    response = run_single_request(apim_subscriptions[0], f"subscription1 run {i + 1}")
    if response.status_code == 429:
        primary_throttle_response = response
        break

if primary_throttle_response is None:
    print("No 429 observed for subscription1 in this run.")
else:
    print("\nReplaying immediately with the other APIM subscription keys...")
    for subscription in apim_subscriptions[1:]:
        run_single_request(subscription, f"{subscription['name']} replay")

    print("\nInterpretation:")
    print("- if another subscription succeeds immediately, APIM's per-subscription counter is likely the blocker")
    print("- if another subscription also gets 429 immediately, a backend/shared throttling layer is more likely the blocker")

# %% [markdown]
# <a id='plot'></a>
# ### 🔍 Analyze Token Rate limiting results

# %%
# plot the results
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [15, 7]
df = pd.DataFrame(api_runs, columns=['Tokens', 'Status Code'])
df['Run'] = range(1, len(df) + 1)
colors = ['red' if str(code).startswith('5') else 'yellow' if str(code).startswith('4') else 'lightblue' for code in df['Status Code']]
ax = df.plot(kind='bar', x='Run', y='Tokens', color=colors, legend=False)
plt.title('Rate Limiting results')
plt.xlabel('Runs')
plt.ylabel('Tokens')
plt.xticks(df['Run'], rotation=0)
for i, val in enumerate(df['Status Code']):
    ax.text(i, 20, '' if int(val) == 200 else 'Status:429', ha='center', va='bottom')
for i, val in enumerate(df['Tokens']):
    ax.text(i, df['Tokens'][i] + 5, '' if int(val) == 0 else val, ha='center', va='bottom')
accumulated_tokens = df['Tokens'].cumsum()
ax.plot(df['Run']-1, accumulated_tokens, color='green', label='Accumulated Tokens')
for i, val in enumerate(accumulated_tokens):
    ax.text(i, val + 6, str(int(val)), ha='center', va='bottom', label='Accumulated Tokens')
plt.show()

# %% [markdown]
# <a id='ratelimit'></a>
# ### 🧪 Test the emit token metric with the configured subscriptions

# %%
import random
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

for i in range(10):
    client = ChatCompletionsClient(
        endpoint=f"{apim_resource_gateway_url}/{inference_api_path}/models",
        credential=AzureKeyCredential(random.choice(apim_subscriptions)['key']),
    )
    response = client.complete(
        messages=[
            SystemMessage(content="You are a sarcastic, unhelpful assistant."),
            UserMessage(content="Can you tell me the time, please?")
        ],
        max_tokens=2048,
        model=models_config[0]['name']
    )
    print("▶️ Run: ", i+1, "🗨️\n", response.choices[0].message.content)

# %% [markdown]
# <a id='kql'></a>
# ### 🔍 Analyze LL Logging with a KQL query
#
# Note that it may take a few minutes for data to become available.

# %%
import pandas as pd

query = "let llmHeaderLogs = ApiManagementGatewayLlmLog \
| where DeploymentName != ''; \
let llmLogsWithSubscriptionId = llmHeaderLogs \
| join kind=leftouter ApiManagementGatewayLogs on CorrelationId \
| project \
    TimeGenerated, SubscriptionId = ApimSubscriptionId, DeploymentName, TotalTokens; \
llmLogsWithSubscriptionId \
| summarize \
    SumTotalTokens      = sum(TotalTokens) \
  by bin(TimeGenerated, 1m), SubscriptionId, DeploymentName \
  | order by TimeGenerated asc"

output = utils.run(f"az monitor log-analytics query -w {log_analytics_id} --analytics-query \"{query}\"", "Retrieved log analytics query output", "Failed to retrieve log analytics query output") 
if output.success and output.json_data:
    table = output.json_data
    display(pd.DataFrame(table))

# %% [markdown]
# <a id='plot'></a>
# ### 🔍 Plot the custom metrics results

# %%
import pandas as pd

# Convert table to DataFrame
df_table = pd.DataFrame(table)

# Convert SumTotalTokens to numeric
df_table['SumTotalTokens'] = pd.to_numeric(df_table['SumTotalTokens'], errors='coerce')

# Convert TimeGenerated to readable time (HH:MM)
df_table['TimeGenerated'] = pd.to_datetime(df_table['TimeGenerated']).dt.strftime('%H:%M')

# Pivot the DataFrame
df_pivot = df_table.pivot(index='TimeGenerated', columns='SubscriptionId', values='SumTotalTokens')

# Plot the pivoted DataFrame
ax = df_pivot.plot(kind='bar', figsize=(15, 7))
ax.set_title('SumTotalTokens by SubscriptionId and TimeGenerated')
ax.set_xlabel('TimeGenerated')
ax.set_ylabel('SumTotalTokens')
ax.legend(title='SubscriptionId')

# %% [markdown]
# <a id='portal'></a>
# ### 🔍 See the metrics on the Azure Portal
#
# Open the Application Insights resource, navigate to the Metrics blade, then select the defined namespace (llm). Choose the metric "Total Tokens" with a Sum aggregation. Then, apply splitting by 'Subscription Id' to view values for each dimension.

# %% [markdown]
# <a id='clean'></a>
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.
# Use the [clean-up-resources notebook](clean-up-resources.ipynb) for that.
